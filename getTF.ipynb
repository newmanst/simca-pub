# %% [markdown]
# ### Affine Transformation Matrix
# This demo code steps through the calls to:
# 1) Calculate the transformation matrix given a bead file,
#
# 2) Conduct visual check for transformation matrix
#
# 3) Save transform for use in ImageAnalysis

# %% [markdown]
# Load helper functions and set scale for thresholding.
# If necessary, scales for thresholding can be adjusted in SA_helper.py

# %%
import tf_helper as tf #import helper functions

# %%
beaddir = "exampleexperiments/bead_files/" #directory for beads

# %% [markdown]
# Calculate the average transform and visually check results.

# %%
avg_tf = tf.get_avg_tfs(beaddir)
tf.check_all_file_w_tf(beaddir, avg_tf)

# %%
#Print average transform calculated 
avg_tf
# Out:
# array([[ 1.00367014e+00,  3.06078807e-03,  2.93276688e-17],
#        [-7.28735905e-03,  9.97353662e-01, -1.27807107e-17],
#        [ 2.58667127e+02, -1.96416906e+00,  1.00000000e+00]])

# %%
# Save to bead directory 
import pickle
pickle.dump(avg_tf, open(beaddir+"LtoRtf.pkl", "wb"))

# %% [markdown]
# Congratulations! You have now made the tranformation matrix and corresponding file to do image registration. Please move on to the next demo jupyter notebook 'ImageAnalysis.ipynb'
